# %% [markdown]
# # Lesson 1  Solution

# %%
import spacy
import en_core_web_sm
import geonamescache
import pandas as pd

# %%
nlp = en_core_web_sm.load()

# %%
gc = geonamescache.GeonamesCache()
countries_cache = gc.get_countries_by_names()
countries_list = list(countries_cache.keys())

# %%
headline = []
with open("headlines.txt") as FileObj:
    for line in FileObj:
        lineStrip = line.rstrip()
        headline.append(lineStrip)

# %%
disease = [None] * len(headline)
country = [None] * len(headline)
city = [None] * len(headline)
for i,lineStrip in headline:
    print(i)
    doc = nlp (lineStrip)
    found_city = False
    found_country = False
    found_disease = False
    possible_diseases = []
    for ent in doc.ents:  
        if ent.text in countries_list and not found_country:
            country[i]= ent.text
            found_country = True
        elif ent.label_ == "GPE" and not found_city : 
            city[i] = ent.text
            found_city = True
        else :
            possible_diseases.append(ent.text)
            found_disease = True
    if not found_city:
        city[i] = "N/A";
    if not found_country:
        country[i] = "N/A"
    if not found_disease:
        disease[i] = "N/A"
    else:
        disease[i] = " ".join(possible_diseases)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9b1550af284a> in <module>
#       2 country = [None] * len(headline)
#       3 city = [None] * len(headline)
# ----> 4 for i,lineStrip in headline:
#       5     print(i)
#       6     doc = nlp (lineStrip)
#
# ValueError: too many values to unpack (expected 2)

# %%
df = pd.DataFrame(list(zip(headline,city,country)), 
               columns =['headline', 'cities', 'ciybtrues'])

# %%
df
# Out:
#                                                headline         cities  \
# 0                              Zika Outbreak Hits Miami          Miami
# 1                       Could Zika Reach New York City?  New York City
# 2                     First Case of Zika in Miami Beach    Miami Beach
# 3               Mystery Virus Spreads in Recife, Brazil         Recife
# 4               Dallas man comes down with case of Zika         Dallas
# ...                                                 ...            ...
# 7413  Authorities are Worried about the Spread of Go...            N/A
# 7414                   Swine Flu re-emerges in La Jolla            N/A
# 7415                  Tuberculosis Outbreak in Hartford            N/A
# 7416  Rumors about Mumps Spreading in New Bedford ha...            N/A
# 7417  Respiratory Syncytial Virus Vaccine is now Req...            N/A
#
#      ciybtrues
# 0          N/A
# 1          N/A
# 2          N/A
# 3       Brazil
# 4          N/A
# ...        ...
# ...
